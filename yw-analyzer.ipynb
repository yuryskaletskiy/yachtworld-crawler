# %%
import json
import codecs
import pandas as pd

# %%
IN_PATH = "samples/yachts-all-60k-90k.json"
OUT_PATH = 'samples/yachts.xlsx'

# %%
# проверяется по-словам. если не все слова но >0 - тип будет составлен из этих слов
TYPES = [
    'Jeanneau Sun Odyssey',
    'Jeanneau Sun Fast',
    
    'Bavaria Cruiser',
    'Bavaria Lagoon',

    'Beneteau Cyclades',
    'Beneteau Oceanis Clipper',
    
    'Dufour',
    'Fast',
    'Legend',
    'Elan Impression',
    'North Wind',
    'Cyclades',
    'Hunter',
    'Gib Sea',
    'Oceanis',
    'Seawolf',
    'Hanse',
    'Harmony',
]

def type_get_weight(t,name_orig):
    name = name_orig.lower()
    words = t.lower().split(" ")

    num_pass = 0
    for w in words:
        if not w in name:
            break

        num_pass = num_pass+1
    if num_pass == 0:
        return (0,"(other)")

    return (num_pass," ".join(words[:num_pass]).upper())

def parse_name(name_orig):
    weights = [type_get_weight(t,name_orig) for t in TYPES]
    sw = sorted(weights, key=lambda w:-1*w[0])
    
    return sw[0][1]

# %%
json_raw = codecs.open(IN_PATH, "r", "utf-8").read()
yw_raw = json.loads(json_raw)
print "yachts loaded: " + str(len(yw_raw))

# flatten specs
for y in yw_raw:
    fs = ""
    thruster = ""
    furling = ""
    
    for (k,v) in y['full_specs'].items():
        ln = k if len(v)==0 else k + ": " + v
        fs = fs + ln + "\n"
        
        lln = ln.lower()
        # special items
        if "thrust" in lln:
            thruster = thruster + ln + " "

        if "furling" in lln:
            furling = furling + ln + " "

    # parse type
    name_full = y['name'].split(u"\u00a0")[1]
    y['Type'] = parse_name(name_full)    
        
    # parse price to eur
    # "price": "EUR\u00a0\u00a090,000 (US$\u00a0100,467)\u00a0",

    tax = ""
    pr_eur = 0
    pr = y["price"].lower()
    if "tax paid" in pr:
        tax = "Paid"
    if "tax not paid" in pr:
        tax = "Not Paid"
    y['Tax'] = tax
    
    # Country
    country = y['located'].split(" ")[-1].strip()
    y["Country"] = country
    
    if pr.startswith("eur"):
        pr_eur = int(pr.split(u"\u00a0\u00a0")[1].split(" ")[0].replace(",",""))
        
    if pr.startswith(u"£"):
        pr_gpb = int(pr.split(u"\u00a0")[1].split(" ")[0].replace(",",""))
        pr_eur = pr_gpb * 1.16 # current rate GPB to EUR
        
    y['Price_KEUR'] = pr_eur/1000
    
    y["full_specs"] = fs
    y["Thruster"] = thruster
    y["Furling"] = furling
    y["FurlingMain"] = "main" in furling.lower()
# Out:
# yachts loaded: 986

# %%
yachts = pd.DataFrame.from_dict(yw_raw)

# %%
yachts
# Out:
#      Country                                            Furling FurlingMain  \
# 0      Malta                    Furling mainsail Furling genoa         True
# 1    Germany                                     Furling genoa        False
# 2     Greece                                                          False
# 3      Italy                                                          False
# 4    Croatia                    Furling mainsail Furling genoa         True
# 5     Greece                                                          False
# 6      Italy                                                          False
# 7    Croatia                                                          False
# 8     Greece                                                          False
# 9     Greece                    Furling mainsail Furling genoa         True
# 10   Croatia                    Furling mainsail Furling genoa         True
# 11     Spain                                                          False
# 12    France                                                          False
# 13    Greece                                                          False
# 14   Kingdom                                     Furling genoa        False
# 15    Greece                                                          False
# 16    Greece                                                          False
# 17    Greece                                                          False
# 18     Spain                    Furling mainsail Furling genoa         True
# 19     Italy  SLOOP RIG WITH IN-MAST FURLING MAIN AND FURLIN...        True
# 20    Greece                                                          False
# 21    Greece                                                          False
# 22    Greece                                                          False
# 23     Italy                                     Furling genoa        False
# 24   Germany                          Furling genoa - new 2011        False
# 25   Croatia                           Furling mainsail - 2013         True
# 26   Croatia                    Furling mainsail Furling genoa         True
# 27     Italy                                     Furling genoa        False
# 28     Spain                                     Furling genoa        False
# 29    Turkey                                                          False
# ..       ...                                                ...         ...
# 956   Greece                                                          False
# 957  Kingdom                                                          False
# 958  Kingdom                                                          False
# 959  Kingdom                                     Furling genoa        False
# 960  Kingdom  Furling mainsail In mast furling Furling fores...        True
# 961  Kingdom  Harken removable drum twin luff groove roller ...       False
# 962    Spain                                                          False
# 963  Kingdom  Vertech in-mast furling main Furlex roller fur...        True
# 964  Germany  Furling genoa - Furlin genoa appr. 38 sqm, app...       False
# 965  Croatia                    Furling mainsail Furling genoa         True
# 966  Kingdom                                                          False
# 967  Kingdom                                                          False
# 968  Kingdom  Sanders furling genoa (2012) Furling Genoa Ful...        True
# 969  Kingdom                                     Furling genoa        False
# 970  Kingdom                                                          False
# 971    Spain                                     Furling genoa        False
# 972  Kingdom                                     Furling genoa        False
# 973  Kingdom                                     Furling genoa        False
# 974  Kingdom  Sobstad in mast furling mainsail and furling g...        True
# 975  Croatia                                     Furling genoa        False
# 976  Croatia                                     Furling genoa        False
# 977  Kingdom                                     Furling genoa        False
# 978   Cyprus                    Furling mainsail Furling genoa         True
# 979  Kingdom                                                          False
# 980  Kingdom                                                          False
# 981  Croatia                    Furling mainsail Furling genoa         True
# 982  Kingdom                                                          False
# 983   France                                     Furling genoa        False
# 984  Kingdom                                                          False
# 985  Kingdom                                                          False
#
#      Price_KEUR       Tax                                   Thruster  \
# 0       89.0000      Paid
# 1       62.0000  Not Paid
# 2       65.0000
# 3       85.0000
# 4       89.0000  Not Paid                              Bow thruster
# 5       69.0000  Not Paid
# 6       90.0000
# 7       79.0000  Not Paid
# 8       69.0000  Not Paid
# 9       73.0000  Not Paid
# 10      78.0000  Not Paid
# 11      79.0000      Paid
# 12      74.0000      Paid
# 13      75.0000
# 14      81.1942      Paid
# 15      80.0000  Not Paid
# 16      85.0000  Not Paid
# 17      77.0000  Not Paid
# 18      89.0000      Paid
# 19      88.1600      Paid                              Bow thruster
# 20      75.0000  Not Paid
# 21      85.0000  Not Paid
# 22      87.0000      Paid
# 23      90.0000      Paid
# 24      79.0000  Not Paid                              Bow thruster
# 25      72.0000  Not Paid                              Bow thruster
# 26      87.0000
# 27      90.0000      Paid
# 28      80.0000      Paid
# 29      87.0000
# ..          ...       ...                                        ...
# 956     90.0000  Not Paid
# 957     87.0000      Paid
# 958     63.7420      Paid
# 959     75.4000      Paid
# 960     63.8000      Paid
# 961     64.9600      Paid
# 962     83.0000  Not Paid
# 963     86.9420      Paid
# 964     68.0000      Paid  Bow thruster - Vetus with remote control
# 965     63.0000  Not Paid
# 966     63.8000      Paid
# 967     72.4420      Paid
# 968     65.5400      Paid
# 969     69.5420  Not Paid
# 970     81.1420      Paid
# 971     69.5942      Paid
# 972     64.9600                                        Bow thruster
# 973     63.5100      Paid
# 974     69.5942      Paid
# 975     76.0000  Not Paid
# 976     65.0000  Not Paid
# 977     63.7420      Paid
# 978     69.0000      Paid               Stern thruster Bow thruster
# 979     80.0400      Paid
# 980     66.1200
# 981     64.0000  Not Paid
# 982     75.3420      Paid
# 983     66.7000
# 984     80.6200      Paid
# 985     67.8600
#
#                          Type  \
# 0        JEANNEAU SUN ODYSSEY
# 1                      DUFOUR
# 2                     (other)
# 3                     (other)
# 4             ELAN IMPRESSION
# 5             BAVARIA CRUISER
# 6           JEANNEAU SUN FAST
# 7             ELAN IMPRESSION
# 8             BAVARIA CRUISER
# 9             BAVARIA CRUISER
# 10          BENETEAU CYCLADES
# 11                 NORTH WIND
# 12          BENETEAU CYCLADES
# 13          BENETEAU CYCLADES
# 14                     DUFOUR
# 15                   CYCLADES
# 16          BENETEAU CYCLADES
# 17          BENETEAU CYCLADES
# 18                       ELAN
# 19       JEANNEAU SUN ODYSSEY
# 20       JEANNEAU SUN ODYSSEY
# 21          BENETEAU CYCLADES
# 22   BENETEAU OCEANIS CLIPPER
# 23       JEANNEAU SUN ODYSSEY
# 24       JEANNEAU SUN ODYSSEY
# 25       JEANNEAU SUN ODYSSEY
# 26       JEANNEAU SUN ODYSSEY
# 27       JEANNEAU SUN ODYSSEY
# 28       JEANNEAU SUN ODYSSEY
# 29       JEANNEAU SUN ODYSSEY
# ..                        ...
# 956                   (other)
# 957                   (other)
# 958                   (other)
# 959                   (other)
# 960          BENETEAU OCEANIS
# 961                  BENETEAU
# 962                   (other)
# 963                   (other)
# 964                   (other)
# 965      JEANNEAU SUN ODYSSEY
# 966                    DUFOUR
# 967  BENETEAU OCEANIS CLIPPER
# 968                   (other)
# 969                    DUFOUR
# 970                   (other)
# 971                   (other)
# 972  BENETEAU OCEANIS CLIPPER
# 973  BENETEAU OCEANIS CLIPPER
# 974  BENETEAU OCEANIS CLIPPER
# 975      JEANNEAU SUN ODYSSEY
# 976      JEANNEAU SUN ODYSSEY
# 977                    LEGEND
# 978                    HUNTER
# 979                   (other)
# 980  BENETEAU OCEANIS CLIPPER
# 981      JEANNEAU SUN ODYSSEY
# 982      JEANNEAU SUN ODYSSEY
# 983                   (other)
# 984                   (other)
# 985                   (other)
#
#                                             full_specs hull_material  \
# 0    Teak sidedecks\nLOA: 13.30 m\nFurling mainsail...    Fiberglass
# 1    LOA: 13.40 m\nFresh Water Tanks: 2 (180 Liters...    Fiberglass
# 2    Engine/Fuel Type: Diesel\nEngine Brand: Volvo\...    Fiberglass
# 3    LOA: 13.30 m\nGenerator\nFresh Water Tanks: (4...    Fiberglass
# 4    Compass\nLOA: 44 ft 0 in\nFurling mainsail\nFr...    Fiberglass
# 5    The Company offers the details of this vessel ...    Fiberglass
# 6    LOA: 13.30 m\nFresh Water Tanks: (400 Liters)\...    Fiberglass
# 962  63429-2969326  36'                         Islas Canarias , Spain
# 963  50289-2871155  36'           Dartmouth, Devon. UK, United Kingdom
# 964  78634-2921696  36'                         Heiligenhafen, Germany
# 965   1590-2943931  36'                                        Croatia
# 966  32024-2639337  36'                                 United Kingdom
# 967  68071-2801566  36'               Isle of Anglesey, United Kingdom
# 968  50289-2890450  36'          Lymington Yacht Haven, United Kingdom
# 969  78505-2956953  36'                       Guernsey, United Kingdom
# 970  73591-2952418  36'             Falmouth, Cornwall, United Kingdom
# 971  76712-2746411  36'                                          Spain
# 972  29066-2979672  36'                     Gillingham, United Kingdom
# 973  76064-2811111  36'                  Isle of Wight, United Kingdom
# 974  29424-2963589  36'                                 United Kingdom
# 975  77387-2912485  36'                                        Croatia
# 976   1590-2989083  36'                                        Croatia
# 977  55189-2883011  36'                Plymouth, Devon, United Kingdom
# 978  79550-2912070  36'                               Limassol, Cyprus
# 979  54509-2973309  36'                         Hamble, United Kingdom
# 980  40712-2991265  36'                        Cumbria, United Kingdom
# 981   1590-2416243  36'                                 Split, Croatia
# 982  29864-2867321  36'                         Hamble, United Kingdom
# 983  29066-2704034  36'                               Normandy, France
# 984  42626-2994150  36'            Beaulieu, Hampshire, United Kingdom
# 985  42024-2923649  36'             Gosport, Hampshire, United Kingdom
#
#                                          name  \
# 0                1992 Jeanneau Sun Odyssey 44
# 1                              1998 Dufour 43
# 2                       1995 Dromor Athena 44
# 3    1999 Cantiere del pardo Grand Soleil 43'
# 4                    2005 Elan Impression 434
# 5                     2005 Bavaria 42 Cruiser
# 6                  2003 Jeanneau Sun Fast 43’
# 7                    2006 Elan 434 IMPRESSION
# 8                     2005 Bavaria 42 Cruiser
# 9                     2005 Bavaria 42 Cruiser
# 10                2007 Beneteau Cyclades 43.4
# 11                        1990 North Wind 435
# 12                2005 Beneteau Cyclades 43.3
# 13                  2007 Beneteau Cyclades 43
# 14                 2003 Dufour 44 Performance
# 15                2007 Cyclades 43.4 S/1111.4
# 16                2007 Beneteau Cyclades 43.4
# 17                2005 Beneteau Cyclades 43.3
# 18                               2001 Elan 45
# 19             2001 Jeanneau Sun Odyssey 43DS
# 20               2002 Jeanneau Sun Odyssey 43
# 21                2007 Beneteau Cyclades 43.4
# 22          2005 Beneteau Oceanis Clipper 423
# 23        2004 Jeanneau Sun Odyssey 43 Legend
# 24               2002 Jeanneau Sun Odyssey 43
# 25               2002 Jeanneau Sun Odyssey 43
# 26               2002 Jeanneau Sun Odyssey 43
# 27        2004 Jeanneau Sun Odyssey 43 Legend
# 28               2001 Jeanneau Sun Odyssey 43
# 29               2001 Jeanneau Sun Odyssey 43
# ..                                        ...
# 956                       1996 X-Yachts X-362
# 957                   1999 Starlight 35 MK II
# 958                   1990 Prout Snowgoose 37
# 959       1998 RIVAL BOWMAN Starlight 35 mkII
# 960               2000 Beneteau Oceanis 36 CC
# 961                  2003 Beneteau First 36.7
# 962                            1993 Najad 360
# 963                          1999 Moody 36 CC
# 964                           1991 Pearson 34
# 965             2007 Jeanneau Sun Odyssey 36i
# 966               2007 Dufour 365 Grand Large
